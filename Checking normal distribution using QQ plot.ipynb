# %%
import numpy as np
from numpy.random import seed
from numpy.random import randn
import matplotlib.pyplot as plt
from statsmodels.graphics.gofplots import qqplot

seed(50)

data_1=randn(100)+50*5

print('mean= %.2f std= %.2f' %(np.mean(data_1), np.std(data_1)))
# Out:
# mean= 250.04 std= 1.08

# %%
plt.hist(data_1)
plt.show()

# %%
qqplot(data_1, line='s')
plt.show()

# %%
data_2= 5*randn(100)-234
print('mean: %.2f std: %.2f' %(np.mean(data_2), np.std(data_2)))
# Out:
# mean: -234.98 std: 5.06

# %%
plt.hist(data_2)
plt.show()

# %%
qqplot(data_2, line='s')
plt.show()
